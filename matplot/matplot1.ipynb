# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,39,48,12,23,67]

# %% [markdown]
# # Give the lable on x&y axis and title on the heading

# %%
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Dataset")
plt.plot(x,y, color='green', linewidth=6, linestyle='dotted')
